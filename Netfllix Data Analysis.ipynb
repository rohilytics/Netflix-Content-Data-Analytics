# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('../Netflix-Content-Data-Analytics/netflix_titles.csv')

# %%
df.head() #Extract top 5 records of the dataset
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail() #Extract last 5 records of the dataset
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.info()  # Get a summary of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()  # Get summary statistics for numerical columns
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.isnull().sum()  # Check for total missing values in each column
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.dtypes #Check datatypes of each column
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.sort_values(by='release_year')  #Sort the DataFrame by values
# Out:
#      show_id     type                               title  \
# 4250   s4251  TV Show   Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                      Prelude to War
# 8205   s8206    Movie                The Battle of Midway
# 8739   s8740    Movie  Why We Fight: The Battle of Russia
# 8763   s8764    Movie     WWII: Report from the Aleutians
# ...      ...      ...                                 ...
# 3         s4  TV Show               Jailbirds New Orleans
# 2         s3  TV Show                           Ganglands
# 18       s19    Movie                           Intrusion
# 1         s2  TV Show                       Blood & Water
# 68       s69    Movie                          Schumacher
#
#                                                director  \
# 4250                                                NaN
# 7790                                        Frank Capra
# 8205                                          John Ford
# ...

# %%
df.duplicated().sum() # Check for and count duplicate rows in the DataFrame
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates() # Remove duplicate rows from the DataFrame

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['title']
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
df[df['title'].str.contains('Home')]
# Out:
#      show_id     type                                              title  \
# 182     s183    Movie                        Welcome Home Roscoe Jenkins
# 186     s187  TV Show                               Hometown Cha-Cha-Cha
# 491     s492    Movie                                         Home Again
# 629     s630    Movie                                    A Way Back Home
# 759     s760    Movie  Fireplace 4K: Classic Crackling Fireplace from...
# 760     s761    Movie  Fireplace 4K: Crackling Birchwood from Firepla...
# 824     s825    Movie                                       Welcome Home
# 846     s847    Movie                                               Home
# 1396   s1397    Movie                                          Homefront
# 1449   s1450  TV Show                                Dream Home Makeover
# 1516   s1517  TV Show                                 Home for Christmas
# 1597   s1598    Movie                                    You Are My Home
# ...

# %% [markdown]
# # Getting the details of the Netflix show "Hometown Cha-Cha-Cha"

# %%
df[df['title'].isin(['Hometown Cha-Cha-Cha'])]  #to show the record of a particular item in any column
# Out:
#     show_id     type                 title director  \
# 186    s187  TV Show  Hometown Cha-Cha-Cha      NaN
#
#                                                   cast country  \
# 186  Shin Min-a, Kim Seon-ho, Lee Sang-yi, Gong Min...     NaN
#
#           date_added  release_year rating  duration  \
# 186  August 29, 2021          2021  TV-14  1 Season
#
#                                              listed_in  \
# 186  International TV Shows, Romantic TV Shows, TV ...
#
#                                            description
# 186  A big-city dentist opens up a practice in a cl...

# %% [markdown]
# # Getting the details of the Netflix show containing keyword "Home"

# %%
df[df['title'].str.contains('Home')]
# Out:
#      show_id     type                                              title  \
# 182     s183    Movie                        Welcome Home Roscoe Jenkins
# 186     s187  TV Show                               Hometown Cha-Cha-Cha
# 491     s492    Movie                                         Home Again
# 629     s630    Movie                                    A Way Back Home
# 759     s760    Movie  Fireplace 4K: Classic Crackling Fireplace from...
# 760     s761    Movie  Fireplace 4K: Crackling Birchwood from Firepla...
# 824     s825    Movie                                       Welcome Home
# 846     s847    Movie                                               Home
# 1396   s1397    Movie                                          Homefront
# 1449   s1450  TV Show                                Dream Home Makeover
# 1516   s1517  TV Show                                 Home for Christmas
# 1597   s1598    Movie                                    You Are My Home
# ...

# %% [markdown]
# # Getting the percentage distribution of all content type

# %%
df['type'].value_counts(normalize=True) * 100  # Percentage distribution
# Out:
# type
# Movie      69.615079
# TV Show    30.384921
# Name: proportion, dtype: float64

# %% [markdown]
# # Top 10 Countries with largest content production

# %%
df['country'].value_counts().head(10)  # Top 10 countries
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
df['cast'].str.split(', ', expand=True).stack().value_counts().head(10)
# Out:
# Anupam Kher         43
# Shah Rukh Khan      35
# Julie Tejwani       33
# Takahiro Sakurai    32
# Naseeruddin Shah    32
# Rupa Bhimani        31
# Om Puri             30
# Akshay Kumar        30
# Yuki Kaji           29
# Amitabh Bachchan    28
# Name: count, dtype: int64

# %%
df['release_year'].value_counts().head(10)
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# Name: count, dtype: int64

# %%
df.groupby(['rating', 'type']).size()
# Out:
# rating    type
# 66 min    Movie         1
# 74 min    Movie         1
# 84 min    Movie         1
# G         Movie        41
# NC-17     Movie         3
# NR        Movie        75
#           TV Show       5
# PG        Movie       287
# PG-13     Movie       490
# R         Movie       797
#           TV Show       2
# TV-14     Movie      1427
#           TV Show     733
# TV-G      Movie       126
#           TV Show      94
# TV-MA     Movie      2062
#           TV Show    1145
# TV-PG     Movie       540
#           TV Show     323
# TV-Y      Movie       131
#           TV Show     176
# TV-Y7     Movie       139
#           TV Show     195
# TV-Y7-FV  Movie         5
#           TV Show       1
# UR        Movie         3
# dtype: int64

# %%
df['listed_in'].str.split(', ', expand=True).stack().value_counts().head(10)
# Out:
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1351
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    763
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64
